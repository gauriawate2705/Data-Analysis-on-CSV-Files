# %% [markdown]
# # Sales Data Analysis
# This notebook performs basic sales data analysis using pandas and matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('sales_data.csv')
data.head()

# %%
data['total_sales'] = data['units_sold'] * data['price_per_unit']
data.groupby('product')['units_sold'].sum()
